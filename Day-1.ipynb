# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
c="python"
print(c)
# Out:
# python

# %%
#   Arithmetic operators
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
d=a-b
d
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
b/a
# Out:
# 2.0

# %%
5/2
# Out:
# 2.5

# %%
b//a
# Out:
# 2

# %%
5//2
# Out:
# 2

# %%
num=50

# %%
a=99
b=25
a%b
# Out:
# 24

# %%
#base ** power
2**3
# Out:
# 8

# %%
3**2
# Out:
# 9

# %%
#relational operators
a=10
b=20
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#logical operator
print("====AND===")
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# ====AND===
# True
# False
# False
# False

# %%
print("====OR===")
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# ====OR===
# True
# True
# True
# False

# %%
print("====NOT====")
print(not True)
print(not False)
# Out:
# ====NOT====
# False
# True

# %%
a=10
b=20
print(a>b or a<b)#True
print(a<b and a<b)#False
# print(a>b or a<b)#True
# Out:
# True
# True

# %%
a=10
b=20
a,b,c=10,20,30
a=b=c=50

# %%
num+=5 #num=num+5
# Out:
# 65

# %%
num-=5

# %%
num*=2
num
# Out:
# 240

# %%
num/=20

# %%
num
# Out:
# 12.0

# %%
#Membership operators:
arr=[1,2,3,4,5,6]
print(10 in arr)
print(100 in arr)
print(10 not in arr)
print(100 not in arr)
# Out:
# False
# False
# True
# True

# %%
a=[1,2,3]
b=a
c=[1,2,3]

# %%
a[0]=100

# %%
b
# Out:
# [100, 2, 3]

# %%
c
# Out:
# [1, 2, 3]

# %%
print(a is b)
print(a is c)
# Out:
# True
# False

# %%
# age=15
# if (condtion):
#     statements
#     statements
#     statements
#     statements

# %% [raw]
# if : if the condtion becomes true it will enter the block
# else : if the previouse condition gets flase it will enter the block
# elif : if the previouse condition gets flase and the current conditon gets true it will enter the block

# %%
print("general flow")
age=12
if age>=18:#False
    print("he is eligible")
print("general flow")
# Out:
# general flow
# general flow

# %%
print("general flow")
age=12
if age>=18:#False
    print("he is eligible")
print("general flow")
# Out:
# general flow
# general flow

# %%
age=3
if age>=18:#False
    print("he is eligible")
else:
    print("he is not eligible")
# Out:
# he is not eligible

# %%
# neg or pos or zero
num=0
if num<0:
    print("-")
elif num>0:
    print("+")
elif num==0:
    print("0")
# Out:
# 0

# %%
num=0
if num<0:#False
    print("-")
elif num>0:#False
    print("+")
else:
    print("0")
# Out:
# 0

# %%
#wap if a num is div of 2 print foo , if a num div of 3 print too or if both print footoo

# %%
num=4
if num%2==0 and num%3==0:#True
    print('footoo')
elif num%3==0:
    print('too')
elif num%2==0 :
    print("foo")
# Out:
# foo
